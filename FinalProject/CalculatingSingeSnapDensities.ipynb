# %%
# %run -i 'DMDensityProfile.py'

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Find the total mass within the limit set
limit = 20 #kpc
steps = 30
snap = 0

#Calculate density profile
density,radii,t = Density(snap,limit,steps)

# %%
#Find what kind of power law the density profile follows
a=Slope(.6,20,density,radii)

rtest=np.linspace(0,limit,steps)
dentest=a[1]*rtest**a[0]
# Out:
# /home/jcalahan/anaconda3/lib/python3.5/site-packages/scipy/optimize/minpack.py:604: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# DMDensityProfile.py:5: RuntimeWarning: divide by zero encountered in power
#   import numpy as np

# %%
#Plot Density and Slope results
plt.plot(radii,density)
plt.plot(rtest,dentest,label='power=%.3f'% a[0])
plt.title('Time since simulation started: %.2f Gyr ' %t,fontsize=13)
plt.legend()
plt.xlabel('Distance from Center of Mass (kpc)',fontsize=13)
plt.ylabel('Density of Dark Matter',fontsize=13)
plt.xscale('linear')
plt.yscale('linear')

# %%
# Out:
# array([ 10.70935805])

# %%
#Find the total mass within the limit set
limit = 20 #kpc
steps = 40
snap = 80
#Find the density profile
density2,radii2,t2 = Density(snap,limit,steps)

# %%
a=Slope(.6,limit,density2,radii2)

rtest=np.linspace(0,limit,steps)
dentest=a[1]*rtest**a[0]
# Out:
# /home/jcalahan/anaconda3/lib/python3.5/site-packages/scipy/optimize/minpack.py:604: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# DMDensityProfile.py:4: RuntimeWarning: divide by zero encountered in power

# %%
plt.plot(radii2,density2)
plt.plot(rtest,dentest,label='power=%.3f'% a[0])
plt.title('Time since simulation started: %.2f Gyr ' %t2)
plt.legend()

# %%
#Find the total mass within the limit set
limit = 20 #kpc
steps = 30
snap = 200

#Find the density profile
density3,radii3,t3 = Density(200,limit,steps)

# %%
#Find the power law that the density profile follows
a=Slope(0,limit,density3,radii3)
rtest=np.linspace(0,limit,steps)
dentest=a[1]*rtest**a[0]
# Out:
# /home/jcalahan/anaconda3/lib/python3.5/site-packages/scipy/optimize/minpack.py:604: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# DMDensityProfile.py:4: RuntimeWarning: divide by zero encountered in power

# %%
plt.plot(radii3,density3)
plt.plot(rtest,dentest,label='power=%.3f'% a[0])
plt.title('Time since simulation started: %.2f Gyr ' %t3)
plt.legend()

# %%
limit = 20 #kpc
steps = 30
snap = 300

density4,radii4,t4 = Density(snap,limit,steps)

# %%
#Find the power law that the density profile follows
a=Slope(0,limit,density4,radii4)
rtest=np.linspace(0,limit,steps)
dentest=a[1]*rtest**a[0]
# Out:
# /home/jcalahan/anaconda3/lib/python3.5/site-packages/scipy/optimize/minpack.py:604: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# DMDensityProfile.py:4: RuntimeWarning: divide by zero encountered in power

# %%
plt.plot(radii4,density4)
plt.plot(rtest,dentest,label='power=%.3f'% a[0])
plt.title('Time since simulation started: %.2f Gyr ' %t4)
plt.legend()

# %%
limit = 20 #kpc
steps = 30
snap = 400

density5,radii5,t5 = Density(snap,limit,steps)

# %%
#Find the power law that the density profile follows
a=Slope(0.6,limit,density5,radii5)
rtest=np.linspace(0,limit,steps)
dentest=a[1]*rtest**a[0]
# Out:
# /home/jcalahan/anaconda3/lib/python3.5/site-packages/scipy/optimize/minpack.py:604: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# DMDensityProfile.py:4: RuntimeWarning: divide by zero encountered in power

# %%
plt.plot(radii5,density5)
plt.plot(rtest,dentest,label='power=%.3f'% a[0])
time=(snap*3)/200
plt.title('Time since simulation started: %.2f Gyr ' %t5)
plt.legend()

# %%
limit = 20 #kpc
steps = 30
snap = 499

density6,radii6,t6 = Density(snap,limit,steps)

# %%
#Find the power law that the density profile follows
a=Slope(1.2,limit,density6,radii6)
rtest=np.linspace(0,limit,steps)
dentest=a[1]*rtest**a[0]
# Out:
# /home/jcalahan/anaconda3/lib/python3.5/site-packages/scipy/optimize/minpack.py:604: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# DMDensityProfile.py:4: RuntimeWarning: divide by zero encountered in power

# %%
plt.plot(radii6,density6)
plt.plot(rtest,dentest,label='power=%.3f'% a[0])
time=(snap*3)/200
plt.title('Time since simulation started: %.2f Gyr ' %t6)
plt.legend()
plt.xscale('linear')
plt.yscale('linear')

# %%
limit = 20 #kpc
steps = 30
snap = 800

density7,radii7,t = Density(snap,limit,steps)

# %%
#Find the power law that the density profile follows
a=Slope(.6,limit,density7,radii7)
rtest=np.linspace(0,limit,steps)
dentest=a[1]*rtest**a[0]
# Out:
# /home/jcalahan/anaconda3/lib/python3.5/site-packages/scipy/optimize/minpack.py:604: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# DMDensityProfile.py:4: RuntimeWarning: divide by zero encountered in power

# %%
plt.plot(radii7,density7)
plt.plot(rtest,dentest,label='power=%.3f'% a[0])
plt.title('Time since simulation started: %.2f Gyr ' %t)
plt.legend()
plt.xscale('linear')
plt.yscale('linear')
plt.xlabel('Distance from Center of Mass (kpc)',fontsize=13)
plt.ylabel('Density of Dark Matter',fontsize=13)

# %%
#This is the odd one
limit = 20 #kpc
steps = 30
snap = 660

density8,radii8,t = Density(snap,limit,steps)

# %%
#Find the power law that the density profile follows
a=Slope(5,limit,density8,radii8)
rtest=np.linspace(0,limit,steps)
dentest=a[1]*rtest**a[0]
# Out:
# /home/jcalahan/anaconda3/lib/python3.5/site-packages/scipy/optimize/minpack.py:604: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# DMDensityProfile.py:4: RuntimeWarning: divide by zero encountered in power

# %%
plt.plot(radii8,density8)
plt.plot(rtest,dentest,label='power=%.3f'% a[0])
plt.title('Time since simulation started: %.2f Gyr ' %t)
plt.legend()
plt.xscale('linear')
plt.yscale('linear')
plt.xlabel('Distance from Center of Mass (kpc)',fontsize=13)
plt.ylabel('Density of Dark Matter',fontsize=13)
plt.ylim(0,6e6)
# Out:
# (0, 6000000.0)
