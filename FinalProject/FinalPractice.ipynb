# %%
# %run -i 'DMDensityProfile.py'

# %%
#Find the total mass within the limit set
limit = 20 #kpc
steps = 30
snap = 0

density,radii = Density(snap,limit,steps)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(radii,density)
time=(snap*3)/200
plt.title('Time since simulation started: %.2f Gyr ' %time)

# %%
#Find the total mass within the limit set
limit = 20 #kpc
steps = 30
snap = 100

density2,radii2 = Density(snap,limit,steps)

# %%
plt.plot(radii2,density2)
time=(snap*3)/200
plt.title('Time since simulation started: %.2f Gyr ' %time)

# %%
#Find the total mass within the limit set
limit = 20 #kpc
steps = 30
snap = 200

density3,radii3 = Density(200,limit,steps)

# %%
plt.plot(radii3,density3)
time=(snap*3)/200
plt.title('Time since simulation started: %.2f Gyr ' %time)

# %%
limit = 20 #kpc
steps = 50
snap = 400

density4,radii4 = Density(snap,limit,steps)

# %%
plt.plot(radii4,density4)
time=(snap*3)/200
plt.title('Time since simulation started: %.2f Gyr ' %time)
