# %%
# %run -i 'DMDensityProfile.py'

# %%
#Find the total mass within the limit set
limit = 20 #kpc
steps = 10

density,radii = Density(0,limit,steps)

# %%
print(density)
# Out:
# [ 44790468.32797103  16059740.28864747   8862051.72570968
#    5727728.47450615   4092434.36933459   2995853.69298927
#    2316155.87333532   1818691.91915591   1453564.03966668]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(radii,density)

# %%
#Find the total mass within the limit set
limit = 8 #kpc
steps = 10

density2,radii2 = Density(0,limit,steps)

# %%
plt.plot(radii2,density2)

# %%
#Find the total mass within the limit set
limit = 3 #kpc
steps = 10

density3,radii3 = Density(0,limit,steps)

# %%
plt.plot(radii3,density3)
